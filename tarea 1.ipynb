# %% [markdown]
# 1 print ("Hola Mundo")

# %% [markdown]
# # CLASE 1
#
# ## Matias Mondragon
#
# ### Esta es la primera clase

# %% [markdown]
# - Variable
# - Tipos de datos
# - Print

# %%
nombre = "Matias" # String
edad = 16 # Entero 
tasa_intereses = 0.15 # Flotando 
activo = True # Booleano

# %%
print(nombre)
print(edad)

print("Mi nombre es", nombre,"y tengo", edad,"años")
# Out:
# Matias
# 16
# Mi nombre es Matias y tengo 16 años

# %%
type (nombre)
# Out:
# str

# %%
type (edad)
# Out:
# int

# %%
type (tasa_intereses)
# Out:
# float

# %%
type(activo)
# Out:
# bool

# %%
print ("hola",nombre)
# Out:
# hola Matias
